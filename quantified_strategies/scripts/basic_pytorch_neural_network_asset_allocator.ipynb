# %% [markdown]
# # Asset Allocation with Pytorch

# %% [markdown]
#  Goal of this notebook is to create a model to combine the signals from the various strategies to create an asset allocation neural network to outperform equally weighted, as Markowitz may not be appropriate as the signals may be to buy or sell the same asset therefore yielding a perfect correlation when active.

# %%
from loguru import logger
from matplotlib import pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
import shutil
import time
from tqdm import tqdm
import typing as t

import viz_neural_network as viz_nn

# %%
from quantified_strategies import loss, ml_utils, plot_utils, strategy_utils, utils
# Out:
# 2024-02-26 21:29:00.303 | INFO     | quantified_strategies.ml_utils:get_device:26 - Running on the CPU

# %%
CASH = "CASH"

# %%
ASSETS = ["SPY", "QQQ", CASH]
# ASSETS = ["SPY", "QQQ", CASH]
ASSETS
# Out:
# ['SPY', 'QQQ', 'CASH']

# %%
LONG_OVERNIGHT_COSTS_DICT = {
    "SPY": 0.507559 / 508.3,
    "QQQ": 0.113025 / 437,
    "XLC": 0.020313 / 78.53,
    "XLE": 0.086145 / 86.25,
    "XLF": 0.040039 / 40.08,
    "XLI": 0.031045 / 120.00,
    "XLK": 0.053141 / 205.50,
    "XLP": 0.019255 / 74.47,
    "XLRE": 0.038212 / 38.28,
    "XLU": 0.015704 / 60.74,
    "XLY": 0.04701 / 181.00,
    "XLV": 0.038038 / 147.10,
}
SHORT_OVERNIGHT_COSTS_DICT = {
    "SPY": 0.127772 / 508.3,
    "QQQ": 0.089958 / 437,
    "XLC": 0.016167 / 78.53,
    "XLE": 0.021686 / 86.25,
    "XLF": 0.010079 / 40.08,
    "XLI": 0.024709 / 120.00,
    "XLK": 0.042296 / 205.50,
    "XLP": 0.015325 / 74.47,
    "XLRE": 0.009619 / 38.28,
    "XLU": 0.012499 / 60.74,
    "XLY": 0.037416 / 181.00,
    "XLV": 0.030275 / 147.10,
}

# %%
# Temporary Values
BORROWING_COSTS = [0 / 10_000 for _ in ASSETS]

# %% [markdown]
# ## Dataset Collection

# %%
def get_data(assets: str | t.List[str], is_classification: bool = True) -> t.Tuple[pd.DataFrame, pd.DataFrame]:

    def get_y() -> pd.DataFrame:
        price_data = [strategy_utils.get_data(ticker=ticker, columns="Adj Close").to_frame(name=ticker) for ticker in assets if ticker != "CASH"]
        price_data = pd.concat(price_data, axis=1)
        return_data = price_data.pct_change()
        if "CASH" in assets:
            return_data["CASH"] = 0.0
        return_data = return_data.shift(-1)
        return_data = return_data.dropna()

        if is_classification:
            return (return_data > 0).astype(int)
        
        return return_data

    def get_X() -> pd.DataFrame:
        strategy_returns = pd.read_csv(f"outputs/strategy_returns.csv", index_col=0, header=[0, 1, 2])
        strategy_returns = strategy_returns.loc[:, strategy_returns.columns.get_level_values(2).isin(assets)]
        strategy_returns.index = pd.DatetimeIndex(strategy_returns.index)
        is_active = ~(strategy_returns.isna())
        is_active = is_active.astype(int)
        return is_active

    assets = assets if isinstance(assets, list) else [assets]

    # Get target variables: these are the returns from entering a position from close to close t+1
    y = get_y()
    
    # Get explanatory variables: these are the signals from the strategies indicating whether to buy or not
    X = get_X()

    X = X.loc[X.index.isin(X.index.intersection(y.index))]
    y = y.loc[y.index.isin(y.index.intersection(X.index))]

    X = X.sort_index()
    y = y.sort_index()

    return X, y

orig_X_total, orig_y_total = get_data(assets=ASSETS, is_classification=False)

# %%
print(f"{orig_X_total.shape = }")
print(f"{orig_y_total.shape = }")
# Out:
# orig_X_total.shape = (6073, 16)
# orig_y_total.shape = (6073, 3)

# %%
TRADE_ID = "trade_id"
STRATEGY_ID = "strategy_id"


def group_trades(X: pd.DataFrame, y: pd.DataFrame) -> t.Tuple[pd.DataFrame, pd.DataFrame]:
    
    new_X = X.copy()
    new_y = y.copy()
    
    # Fetch trade id i.e. change in strategy activation
    new_X[STRATEGY_ID] = new_X.apply(lambda x: sum([v * 10 ** i for i, v in enumerate(x.values)]), axis=1)
    new_X[TRADE_ID] = (new_X[STRATEGY_ID].diff().abs().fillna(1.0) > 0).cumsum()
    
    # Copy trade id to target/asset return dataframe
    new_y[TRADE_ID] = new_X[TRADE_ID]
    
    # Find trade id to first trade date
    trades = new_y.reset_index().set_index(TRADE_ID)["Date"]
    trades = trades[~trades.index.duplicated()]
    trades_to_date_dict = trades.to_dict()
    
    # Find return for each trade id
    new_y = new_y.groupby(by=TRADE_ID)[ASSETS].apply(lambda ret: strategy_utils.get_cumulative_return(returns=ret, total=True))
    new_y.index = new_y.index.map(trades_to_date_dict)
    new_y.index.name = "Date"

    X = X.loc[X.index.isin(new_y.index)].copy()

    return X, new_y

orig_X_total, orig_y_total = group_trades(X=orig_X_total, y=orig_y_total)

# %%
orig_X_total.head(1)
# Out:
#            event_trading       overnight_trading            seasonal_trading  \
#               super_bowl     short_term_reversal     buy_when_yields_are_low
#                      SPY QQQ                 SPY QQQ                     SPY
# Date
# 2000-01-03             0   0                   0   0                       0
#
#                                                                              \
#                pay_day_strategy     santa_claus_strategy     september_bear
#            QQQ              SPY QQQ                  SPY QQQ            SPY
# Date
# 2000-01-03   0                1   1                    1   1              0
#
#
#                tax_day_strategy     turn_around_tuesday_strategy
#            QQQ              SPY QQQ                          SPY QQQ
# Date
# 2000-01-03   0                0   0                            0   0

# %%
orig_y_total.head(5)
# Out:
#                  SPY       QQQ  CASH
# Date
# 2000-01-03 -0.039107 -0.068602   0.0
# 2000-01-04 -0.014310 -0.092422   0.0
# 2000-01-06  0.058075  0.123683   0.0
# 2000-01-07 -0.037092  0.018055   0.0
# 2000-01-24  0.011356  0.015007   0.0

# %%
assert orig_X_total.dropna().shape[0] == orig_X_total.shape[0]
assert orig_y_total.dropna().shape[0] == orig_y_total.shape[0]

# %% [markdown]
# ## Create Pytorch Model

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim

# %% [markdown]
# ### Define `device` to use when training model

# %%
DEVICE = ml_utils.get_device()
DEVICE
# Out:
# 2024-02-26 21:29:04.121 | INFO     | quantified_strategies.ml_utils:get_device:26 - Running on the CPU
# device(type='cpu')

# %%
class Net(nn.Module):

    DEFAULT_LAYER_SIZES: t.List[int] = [8, 16, 8]
    DEFAULT_ALLOW_NEGATIVE_WEIGHTS: bool = False

    # Used when more than one asset is being traded, enables leverage.
    DEFAULT_MAX_WEIGHT: float = 1.0
    DEFAULT_MIN_WEIGHT: float = 0.0
    
    # Model Type: used to save model
    MODEL_TYPE: str = "nn"
    
    def __init__(self, input_shape: int, output_shape: int, layer_sizes: t.List[int] = DEFAULT_LAYER_SIZES, 
                 allow_negative_weights: bool = DEFAULT_ALLOW_NEGATIVE_WEIGHTS, 
                 max_weight: float = None, min_weight: float = None):
        super().__init__()
        
        self.input_shape: int = input_shape
        self.output_shape: int = output_shape
        self.layer_sizes: t.List[int] = layer_sizes
        
        self.allow_negative_weights: bool = allow_negative_weights

        if (max_weight is None and min_weight is None) or self.output_shape == 1:
            max_weight = Net.DEFAULT_MAX_WEIGHT
            min_weight = Net.DEFAULT_MIN_WEIGHT
        elif max_weight is None and min_weight is not None:
            max_weight = -min_weight * (self.output_shape - 1) + 1
        elif max_weight is not None and min_weight is None:
            min_weight = -(max_weight - 1) / (self.output_shape - 1)
        else:
            pass

        # Assert MAX > MIN
        assert max_weight > min_weight, f"'max_weight' must be larger than 'min_weight': provided {max_weight = } and {min_weight = }"
        # Assert MAX + (n - 1) * MIN
        assert max_weight + (self.output_shape - 1) * min_weight == 1, f"'max_weight' plus (n - 1) * 'min_weight' should be equal to 1: " +\
            f"{max_weight} + {self.output_shape - 1} * {min_weight} = {max_weight + (self.output_shape - 1) * min_weight}"
        
        self.allow_negative_weights: bool = min_weight < 0
        self.max_weight: float = max_weight
        self.min_weight: float = min_weight
        self._max_weight: float = max_weight - 1 / self.output_shape
        self._min_weight: float = min_weight - 1 / self.output_shape
        
        last_shape = self.input_shape
        for i, layer_size in enumerate(self.layer_sizes):
            setattr(self, f"fc{i}", nn.Linear(last_shape, layer_size))
            # setattr(self, f"dropout{i}", nn.Dropout(p=0.2))
            last_shape = layer_size
        self.fc_output = nn.Linear(last_shape, self.output_shape)

    def forward(self, x):

        for i, _ in enumerate(self.layer_sizes):
            x = getattr(self, f"fc{i}")(x)
            # x = F.relu(x)
            # x = F.leaky_relu(x)
            x = F.elu(x)
            # x = getattr(self, f"dropout{i}")(x)

        x = self.fc_output(x)

        if self.output_shape == 1:
            if self.allow_negative_weights:
                # Boundaries: (-1, +1)
                output = F.tanh(x)
            else:
                # Boundaries: (0, +1)
                output = F.sigmoid(x)
        else:
            # Boundaries: (min_weight, max_weight), Sum: 1.0
            output = F.softmax(x, dim=1)
            output = (self._max_weight - self._min_weight) * output + self._min_weight + 1 / self.output_shape

        return output

    @staticmethod
    def translate(X: torch.Tensor, y: torch.Tensor, **kwargs) -> t.Tuple[torch.Tensor, torch.Tensor]:
        return X, y

    @staticmethod
    def load(input_shape: int, output_shape: int, name: str = "latest"):
        
        PATH = Path(os.getcwd())
        model_dict = torch.load(PATH / f"outputs/models/{Net.MODEL_TYPE}-model-{name}-state.dict")
        
        net = Net(input_shape=input_shape, output_shape=output_shape)
        net.load_state_dict(model_dict)
        net.eval()
        
        return net

    def save(self, name: str) -> None:
        PATH = Path(os.getcwd())
        torch.save(self.state_dict(), PATH / f"outputs/models/{self.MODEL_TYPE}-model-{name}-state.dict")
        shutil.copy(PATH / f"outputs/models/{self.MODEL_TYPE}-model-{name}-state.dict", 
                    PATH / f"outputs/models/{self.MODEL_TYPE}-model-latest-state.dict")
        return


def example():

    # Define input and output sizes for neural network
    INPUT_SHAPE = 10
    OUTPUT_SHAPE = 2
    print(f"Input Shape = {INPUT_SHAPE}, Output Shape = {OUTPUT_SHAPE}")

    # Generate example data
    N_SAMPLES = 10
    X_sample = torch.randn(N_SAMPLES, INPUT_SHAPE)
    y_sample = torch.randn(N_SAMPLES, 1)
    print(f"{X_sample.shape = }, {y_sample.shape = }")
    
    X_sample_translated, y_sample_translated = Net.translate(X=X_sample, y=y_sample)
    print(f"{X_sample_translated.shape = }, {y_sample_translated.shape = }")

    X_sample_translated = X_sample_translated.to(device=DEVICE)
    y_sample_translated = y_sample_translated.to(device=DEVICE)

    # Initiate Network
    my_net = Net(input_shape=INPUT_SHAPE, output_shape=OUTPUT_SHAPE, layer_sizes=[5, 10, 5], allow_negative_weights=False).to(device=DEVICE)
    output = my_net.forward(x=X_sample_translated)
    print(f"{output.shape = }")
    print(f"{output = }")

    my_net = Net(input_shape=INPUT_SHAPE, output_shape=OUTPUT_SHAPE, layer_sizes=[8, 16, 8], allow_negative_weights=True).to(device=DEVICE)
    output = my_net.forward(x=X_sample_translated)
    print(f"{output.shape = }")
    print(f"{output = }")

    my_net = Net(input_shape=INPUT_SHAPE, output_shape=OUTPUT_SHAPE, layer_sizes=[8, 16, 8], 
                 allow_negative_weights=True, max_weight=2.0, min_weight=-1.0).to(device=DEVICE)
    output = my_net.forward(x=X_sample_translated)
    print(f"{output.shape = }")
    print(f"{output = }")
    
    return

example()
# Out:
# Input Shape = 10, Output Shape = 2
# X_sample.shape = torch.Size([10, 10]), y_sample.shape = torch.Size([10, 1])
# X_sample_translated.shape = torch.Size([10, 10]), y_sample_translated.shape = torch.Size([10, 1])
# output.shape = torch.Size([10, 2])
# output = tensor([[0.5602, 0.4398],
#         [0.5438, 0.4562],
#         [0.5552, 0.4448],
#         [0.5459, 0.4541],
#         [0.5879, 0.4121],
#         [0.5600, 0.4400],
#         [0.5489, 0.4511],
#         [0.5646, 0.4354],
#         [0.5583, 0.4417],
#         [0.5514, 0.4486]], grad_fn=<AddBackward0>)
# output.shape = torch.Size([10, 2])
# output = tensor([[0.6223, 0.3777],
#         [0.5901, 0.4099],
#         [0.5866, 0.4134],
#         [0.6078, 0.3922],
#         [0.6115, 0.3885],
#         [0.6078, 0.3922],
#         [0.5984, 0.4016],
#         [0.5965, 0.4035],
#         [0.5983, 0.4017],
#         [0.6439, 0.3561]], grad_fn=<AddBackward0>)
# output.shape = torch.Size([10, 2])
# output = tensor([[0.5224, 0.4776],
#         [0.4812, 0.5188],
#         [0.5491, 0.4509],
#         [0.3953, 0.6047],
#         [0.3569, 0.6431],
#         [0.4296, 0.5704],
#         [0.4167, 0.5833],
#         [0.4667, 0.5333],
#         [0.5577, 0.4423],
#         [0.5149, 0.4851]], grad_fn=<AddBackward0>)

# %%
INPUT_SHAPE = 10
OUTPUT_SHAPE = 2
my_net = Net(input_shape=INPUT_SHAPE, output_shape=OUTPUT_SHAPE, layer_sizes=[5, 10, 5, 4], allow_negative_weights=False).to(device=DEVICE)
my_net
# Out:
# Net(
#   (fc0): Linear(in_features=10, out_features=5, bias=True)
#   (fc1): Linear(in_features=5, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=5, bias=True)
#   (fc3): Linear(in_features=5, out_features=4, bias=True)
#   (fc_output): Linear(in_features=4, out_features=2, bias=True)
# )

# %% [markdown]
# ### Translate Data to Correct Format

# %%
X_total, y_total = ml_utils.convert_data_to_tensors(X=orig_X_total, y=orig_y_total)
X_total, y_total = Net.translate(X=X_total, y=y_total)
X_train, X_test, y_train, y_test = ml_utils.split_data(X=X_total, y=y_total)
print(f"{X_train.shape = }")
print(f"{y_train.shape = }")
print(f"{X_test.shape = }")
print(f"{y_test.shape = }")
# Out:
# X_train.shape = torch.Size([1626, 16])
# y_train.shape = torch.Size([1626, 3])
# X_test.shape = torch.Size([698, 16])
# y_test.shape = torch.Size([698, 3])

# %% [markdown]
# ### Global Model Training Parameters

# %%
LOSS_FUNCTION = loss.my_cagr_loss

MAXIMIZE_LOSS = True

BATCH_SIZE = 64
EPOCHS = 2_000
TEST_BATCH_SIZE = 128
LEARNING_RATE = 0.001

STORE = True

assert BATCH_SIZE <= X_train.shape[0]
assert TEST_BATCH_SIZE <= X_test.shape[0]

# %% [markdown]
# ### Model Training Functions

# %% [markdown]
# ## Model Training

# %%
INPUT_SHAPE = X_train.shape[-1]
OUTPUT_SHAPE = y_train.shape[-1]

print(f"Input Shape: {INPUT_SHAPE}, Output Shape: {OUTPUT_SHAPE}")
# Out:
# Input Shape: 16, Output Shape: 3

# %%
ALLOW_NEGATIVE_WEIGHTS = False

MAX_LEVERAGE_WEIGHT = 1.5
MIN_LEVERAGE_WEIGHT = (MAX_LEVERAGE_WEIGHT - 1) / (OUTPUT_SHAPE - 1)

MAX_WEIGHT = MAX_LEVERAGE_WEIGHT if ALLOW_NEGATIVE_WEIGHTS else 1.0
MIN_WEIGHT = -MIN_LEVERAGE_WEIGHT if ALLOW_NEGATIVE_WEIGHTS else 0.0

# MAX_WEIGHT = 1.5
# MIN_WEIGHT = None

print(f"Max. Weight: {MAX_WEIGHT}, Min. Weight: {MIN_WEIGHT}")
# Out:
# Max. Weight: 1.0, Min. Weight: 0.0

# %%
my_net = Net(input_shape=INPUT_SHAPE, output_shape=OUTPUT_SHAPE, layer_sizes=[8, 16, 8], 
             allow_negative_weights=ALLOW_NEGATIVE_WEIGHTS, max_weight=MAX_WEIGHT, min_weight=MIN_WEIGHT).to(device=DEVICE)
my_net
# Out:
# Net(
#   (fc0): Linear(in_features=16, out_features=8, bias=True)
#   (fc1): Linear(in_features=8, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=8, bias=True)
#   (fc_output): Linear(in_features=8, out_features=3, bias=True)
# )

# %%
print(f"Max. Weight: {my_net.max_weight}, Min. Weight: {my_net.min_weight}")
# Out:
# Max. Weight: 1.0, Min. Weight: 0.0

# %%
ml_utils.train(net=my_net, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, loss_fn=LOSS_FUNCTION, 
               lr=LEARNING_RATE, batch_size=BATCH_SIZE, epochs=EPOCHS, maximize_loss=MAXIMIZE_LOSS, store=STORE,
               borrowing_costs=BORROWING_COSTS,
              )
# Out:
# 2024-02-26 21:29:15.198 | INFO     | quantified_strategies.ml_utils:train:142 - Training: '1708982955'
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 199.12it/s]
# 2024-02-26 21:29:15.411 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 0 / 2000, Loss: 3.2115, Val Loss: 12.3727,Hit Rate: 54.43%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 151.95it/s]
# 2024-02-26 21:29:15.652 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 1 / 2000, Loss: 3.3891, Val Loss: 12.5420,Hit Rate: 54.61%, Val Hit Rate: 57.59%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 172.69it/s]
# 2024-02-26 21:29:15.877 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 2 / 2000, Loss: 3.6275, Val Loss: 12.7518,Hit Rate: 54.61%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.88it/s]
# 2024-02-26 21:29:16.089 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 3 / 2000, Loss: 3.9589, Val Loss: 13.0117,Hit Rate: 54.55%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 158.14it/s]
# 2024-02-26 21:29:16.346 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 4 / 2000, Loss: 4.4131, Val Loss: 13.3216,Hit Rate: 54.49%, Val Hit Rate: 57.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 167.45it/s]
# 2024-02-26 21:29:16.603 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 5 / 2000, Loss: 4.9698, Val Loss: 13.6495,Hit Rate: 54.61%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 140.17it/s]
# 2024-02-26 21:29:16.876 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 6 / 2000, Loss: 5.5373, Val Loss: 13.9248,Hit Rate: 54.74%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 152.45it/s]
# 2024-02-26 21:29:17.137 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 7 / 2000, Loss: 6.0654, Val Loss: 14.0989,Hit Rate: 54.86%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 141.79it/s]
# 2024-02-26 21:29:17.390 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 8 / 2000, Loss: 6.6042, Val Loss: 14.1728,Hit Rate: 54.80%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 196.19it/s]
# 2024-02-26 21:29:17.593 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 9 / 2000, Loss: 7.2134, Val Loss: 14.1621,Hit Rate: 54.74%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 185.02it/s]
# 2024-02-26 21:29:17.820 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 10 / 2000, Loss: 7.9000, Val Loss: 14.0643,Hit Rate: 54.74%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 187.64it/s]
# 2024-02-26 21:29:18.036 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 11 / 2000, Loss: 8.6308, Val Loss: 13.8688,Hit Rate: 54.86%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.22it/s]
# 2024-02-26 21:29:18.249 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 12 / 2000, Loss: 9.3567, Val Loss: 13.5744,Hit Rate: 55.04%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 161.42it/s]
# 2024-02-26 21:29:18.474 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 13 / 2000, Loss: 10.0291, Val Loss: 13.2298,Hit Rate: 54.74%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 157.07it/s]
# 2024-02-26 21:29:18.730 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 14 / 2000, Loss: 10.6025, Val Loss: 12.8961,Hit Rate: 54.67%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 159.45it/s]
# 2024-02-26 21:29:18.988 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 15 / 2000, Loss: 11.0745, Val Loss: 12.5897,Hit Rate: 54.74%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 139.75it/s]
# 2024-02-26 21:29:19.254 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 16 / 2000, Loss: 11.4977, Val Loss: 12.2690,Hit Rate: 54.74%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 173.27it/s]
# 2024-02-26 21:29:19.493 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 17 / 2000, Loss: 11.9495, Val Loss: 11.8721,Hit Rate: 54.49%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 142.28it/s]
# 2024-02-26 21:29:19.752 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 18 / 2000, Loss: 12.3894, Val Loss: 11.4703,Hit Rate: 54.18%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 172.82it/s]
# 2024-02-26 21:29:19.972 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 19 / 2000, Loss: 12.7053, Val Loss: 11.2343,Hit Rate: 54.18%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 161.43it/s]
# 2024-02-26 21:29:20.208 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 20 / 2000, Loss: 12.9378, Val Loss: 11.1318,Hit Rate: 54.31%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 144.77it/s]
# 2024-02-26 21:29:20.475 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 21 / 2000, Loss: 13.1214, Val Loss: 11.0722,Hit Rate: 54.24%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 159.01it/s]
# 2024-02-26 21:29:20.719 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 22 / 2000, Loss: 13.2763, Val Loss: 11.0209,Hit Rate: 54.18%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 159.90it/s]
# 2024-02-26 21:29:20.972 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 23 / 2000, Loss: 13.4170, Val Loss: 10.9756,Hit Rate: 54.18%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 141.66it/s]
# 2024-02-26 21:29:21.253 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 24 / 2000, Loss: 13.5505, Val Loss: 10.9339,Hit Rate: 54.24%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 160.55it/s]
# 2024-02-26 21:29:21.480 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 25 / 2000, Loss: 13.6828, Val Loss: 10.8945,Hit Rate: 54.24%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 156.13it/s]
# 2024-02-26 21:29:21.883 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 26 / 2000, Loss: 13.8080, Val Loss: 10.8588,Hit Rate: 54.43%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 136.76it/s]
# 2024-02-26 21:29:22.160 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 27 / 2000, Loss: 13.9213, Val Loss: 10.8290,Hit Rate: 54.43%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 143.34it/s]
# 2024-02-26 21:29:22.436 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 28 / 2000, Loss: 14.0202, Val Loss: 10.8123,Hit Rate: 54.43%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 151.98it/s]
# 2024-02-26 21:29:22.707 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 29 / 2000, Loss: 14.1096, Val Loss: 10.8099,Hit Rate: 54.49%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 149.36it/s]
# 2024-02-26 21:29:22.976 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 30 / 2000, Loss: 14.1919, Val Loss: 10.8159,Hit Rate: 54.43%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 154.72it/s]
# 2024-02-26 21:29:23.226 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 31 / 2000, Loss: 14.2682, Val Loss: 10.8254,Hit Rate: 54.43%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 147.63it/s]
# 2024-02-26 21:29:23.502 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 32 / 2000, Loss: 14.3421, Val Loss: 10.8373,Hit Rate: 54.43%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 140.48it/s]
# 2024-02-26 21:29:23.766 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 33 / 2000, Loss: 14.4124, Val Loss: 10.8492,Hit Rate: 54.31%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 172.57it/s]
# 2024-02-26 21:29:23.988 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 34 / 2000, Loss: 14.4804, Val Loss: 10.8588,Hit Rate: 54.18%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 158.02it/s]
# 2024-02-26 21:29:24.234 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 35 / 2000, Loss: 14.5471, Val Loss: 10.8671,Hit Rate: 54.18%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 164.96it/s]
# 2024-02-26 21:29:24.473 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 36 / 2000, Loss: 14.6115, Val Loss: 10.8731,Hit Rate: 54.18%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 147.28it/s]
# 2024-02-26 21:29:24.738 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 37 / 2000, Loss: 14.6759, Val Loss: 10.8790,Hit Rate: 54.12%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 150.59it/s]
# 2024-02-26 21:29:24.985 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 38 / 2000, Loss: 14.7390, Val Loss: 10.8850,Hit Rate: 54.18%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 146.82it/s]
# 2024-02-26 21:29:25.235 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 39 / 2000, Loss: 14.8010, Val Loss: 10.8910,Hit Rate: 54.12%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 159.90it/s]
# 2024-02-26 21:29:25.485 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 40 / 2000, Loss: 14.8618, Val Loss: 10.8981,Hit Rate: 54.12%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 140.64it/s]
# 2024-02-26 21:29:25.775 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 41 / 2000, Loss: 14.9226, Val Loss: 10.9076,Hit Rate: 54.00%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 131.26it/s]
# 2024-02-26 21:29:26.064 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 42 / 2000, Loss: 14.9834, Val Loss: 10.9172,Hit Rate: 54.00%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 134.00it/s]
# 2024-02-26 21:29:26.341 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 43 / 2000, Loss: 15.0454, Val Loss: 10.9303,Hit Rate: 54.00%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 161.36it/s]
# 2024-02-26 21:29:26.571 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 44 / 2000, Loss: 15.1086, Val Loss: 10.9434,Hit Rate: 54.00%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 135.73it/s]
# 2024-02-26 21:29:26.856 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 45 / 2000, Loss: 15.1718, Val Loss: 10.9589,Hit Rate: 54.00%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 144.39it/s]
# 2024-02-26 21:29:27.133 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 46 / 2000, Loss: 15.2373, Val Loss: 10.9756,Hit Rate: 53.94%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 146.40it/s]
# 2024-02-26 21:29:27.396 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 47 / 2000, Loss: 15.3041, Val Loss: 10.9947,Hit Rate: 54.00%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 161.43it/s]
# 2024-02-26 21:29:27.634 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 48 / 2000, Loss: 15.3732, Val Loss: 11.0161,Hit Rate: 54.06%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 169.84it/s]
# 2024-02-26 21:29:27.875 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 49 / 2000, Loss: 15.4448, Val Loss: 11.0424,Hit Rate: 54.12%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 158.04it/s]
# 2024-02-26 21:29:28.138 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 50 / 2000, Loss: 15.5210, Val Loss: 11.0734,Hit Rate: 54.12%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 168.77it/s]
# 2024-02-26 21:29:28.368 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 51 / 2000, Loss: 15.6033, Val Loss: 11.1139,Hit Rate: 54.06%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 175.58it/s]
# 2024-02-26 21:29:28.594 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 52 / 2000, Loss: 15.6951, Val Loss: 11.1675,Hit Rate: 54.00%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 151.32it/s]
# 2024-02-26 21:29:28.833 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 53 / 2000, Loss: 15.8048, Val Loss: 11.2462,Hit Rate: 53.87%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 167.65it/s]
# 2024-02-26 21:29:29.067 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 54 / 2000, Loss: 15.9431, Val Loss: 11.3678,Hit Rate: 53.94%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 172.11it/s]
# 2024-02-26 21:29:29.306 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 55 / 2000, Loss: 16.1207, Val Loss: 11.5585,Hit Rate: 53.75%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 174.43it/s]
# 2024-02-26 21:29:29.528 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 56 / 2000, Loss: 16.3317, Val Loss: 11.8291,Hit Rate: 53.63%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 167.65it/s]
# 2024-02-26 21:29:29.766 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 57 / 2000, Loss: 16.5391, Val Loss: 12.1355,Hit Rate: 53.81%, Val Hit Rate: 57.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 170.93it/s]
# 2024-02-26 21:29:29.988 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 58 / 2000, Loss: 16.7251, Val Loss: 12.4097,Hit Rate: 53.81%, Val Hit Rate: 57.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 169.87it/s]
# 2024-02-26 21:29:30.218 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 59 / 2000, Loss: 16.8955, Val Loss: 12.6362,Hit Rate: 53.94%, Val Hit Rate: 57.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 176.79it/s]
# 2024-02-26 21:29:30.439 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 60 / 2000, Loss: 17.0541, Val Loss: 12.8281,Hit Rate: 53.94%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 189.70it/s]
# 2024-02-26 21:29:30.642 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 61 / 2000, Loss: 17.2019, Val Loss: 13.0069,Hit Rate: 54.18%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.23it/s]
# 2024-02-26 21:29:30.866 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 62 / 2000, Loss: 17.3414, Val Loss: 13.1893,Hit Rate: 54.24%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 172.13it/s]
# 2024-02-26 21:29:31.086 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 63 / 2000, Loss: 17.4785, Val Loss: 13.3944,Hit Rate: 54.24%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 193.25it/s]
# 2024-02-26 21:29:31.277 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 64 / 2000, Loss: 17.6239, Val Loss: 13.6435,Hit Rate: 54.00%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 176.81it/s]
# 2024-02-26 21:29:31.501 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 65 / 2000, Loss: 17.7944, Val Loss: 13.9546,Hit Rate: 53.81%, Val Hit Rate: 57.88%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 183.71it/s]
# 2024-02-26 21:29:31.722 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 66 / 2000, Loss: 17.9708, Val Loss: 14.2574,Hit Rate: 54.12%, Val Hit Rate: 57.59%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 154.70it/s]
# 2024-02-26 21:29:31.962 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 67 / 2000, Loss: 18.1115, Val Loss: 14.4458,Hit Rate: 54.06%, Val Hit Rate: 57.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 165.55it/s]
# 2024-02-26 21:29:32.189 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 68 / 2000, Loss: 18.2199, Val Loss: 14.5686,Hit Rate: 53.94%, Val Hit Rate: 57.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.89it/s]
# 2024-02-26 21:29:32.407 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 69 / 2000, Loss: 18.3094, Val Loss: 14.6675,Hit Rate: 54.18%, Val Hit Rate: 57.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 133.96it/s]
# 2024-02-26 21:29:32.692 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 70 / 2000, Loss: 18.3880, Val Loss: 14.7581,Hit Rate: 54.31%, Val Hit Rate: 57.59%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 137.86it/s]
# 2024-02-26 21:29:32.975 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 71 / 2000, Loss: 18.4596, Val Loss: 14.8392,Hit Rate: 54.31%, Val Hit Rate: 57.74%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 126.10it/s]
# 2024-02-26 21:29:33.277 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 72 / 2000, Loss: 18.5251, Val Loss: 14.9095,Hit Rate: 54.37%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 133.64it/s]
# 2024-02-26 21:29:33.569 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 73 / 2000, Loss: 18.5847, Val Loss: 14.9655,Hit Rate: 54.37%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 143.42it/s]
# 2024-02-26 21:29:33.845 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 74 / 2000, Loss: 18.6372, Val Loss: 15.0108,Hit Rate: 54.31%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 142.12it/s]
# 2024-02-26 21:29:34.127 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 75 / 2000, Loss: 18.6849, Val Loss: 15.0466,Hit Rate: 54.24%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 143.16it/s]
# 2024-02-26 21:29:34.389 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 76 / 2000, Loss: 18.7278, Val Loss: 15.0740,Hit Rate: 54.31%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 157.04it/s]
# 2024-02-26 21:29:34.655 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 77 / 2000, Loss: 18.7647, Val Loss: 15.0979,Hit Rate: 54.31%, Val Hit Rate: 58.45%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 139.91it/s]
# 2024-02-26 21:29:34.939 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 78 / 2000, Loss: 18.7981, Val Loss: 15.1169,Hit Rate: 54.31%, Val Hit Rate: 58.31%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 126.69it/s]
# 2024-02-26 21:29:35.243 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 79 / 2000, Loss: 18.8291, Val Loss: 15.1336,Hit Rate: 54.37%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 136.34it/s]
# 2024-02-26 21:29:35.537 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 80 / 2000, Loss: 18.8565, Val Loss: 15.1491,Hit Rate: 54.37%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 129.89it/s]
# 2024-02-26 21:29:35.831 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 81 / 2000, Loss: 18.8828, Val Loss: 15.1634,Hit Rate: 54.43%, Val Hit Rate: 58.17%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 137.49it/s]
# 2024-02-26 21:29:36.111 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 82 / 2000, Loss: 18.9066, Val Loss: 15.1753,Hit Rate: 54.49%, Val Hit Rate: 58.02%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 136.97it/s]
# 2024-02-26 21:29:36.385 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 83 / 2000, Loss: 18.9281, Val Loss: 15.1873,Hit Rate: 60.33%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 150.64it/s]
# 2024-02-26 21:29:36.624 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 84 / 2000, Loss: 18.9483, Val Loss: 15.1980,Hit Rate: 60.33%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 168.76it/s]
# 2024-02-26 21:29:36.855 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 85 / 2000, Loss: 18.9686, Val Loss: 15.2075,Hit Rate: 60.27%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 165.48it/s]
# 2024-02-26 21:29:37.093 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 86 / 2000, Loss: 18.9865, Val Loss: 15.2171,Hit Rate: 60.39%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 144.80it/s]
# 2024-02-26 21:29:37.376 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 87 / 2000, Loss: 19.0032, Val Loss: 15.2266,Hit Rate: 60.46%, Val Hit Rate: 62.03%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 127.36it/s]
# 2024-02-26 21:29:37.678 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 88 / 2000, Loss: 19.0198, Val Loss: 15.2349,Hit Rate: 60.46%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 150.68it/s]
# 2024-02-26 21:29:37.943 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 89 / 2000, Loss: 19.0353, Val Loss: 15.2445,Hit Rate: 60.39%, Val Hit Rate: 62.03%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 175.67it/s]
# 2024-02-26 21:29:38.179 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 90 / 2000, Loss: 19.0508, Val Loss: 15.2528,Hit Rate: 60.46%, Val Hit Rate: 62.18%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 132.94it/s]
# 2024-02-26 21:29:38.466 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 91 / 2000, Loss: 19.0651, Val Loss: 15.2612,Hit Rate: 60.39%, Val Hit Rate: 62.03%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 189.68it/s]
# 2024-02-26 21:29:38.690 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 92 / 2000, Loss: 19.0794, Val Loss: 15.2707,Hit Rate: 60.46%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 159.46it/s]
# 2024-02-26 21:29:38.924 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 93 / 2000, Loss: 19.0938, Val Loss: 15.2802,Hit Rate: 60.52%, Val Hit Rate: 61.75%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 135.36it/s]
# 2024-02-26 21:29:39.213 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 94 / 2000, Loss: 19.1069, Val Loss: 15.2910,Hit Rate: 60.52%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 157.52it/s]
# 2024-02-26 21:29:39.455 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 95 / 2000, Loss: 19.1212, Val Loss: 15.3041,Hit Rate: 60.46%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 160.43it/s]
# 2024-02-26 21:29:39.710 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 96 / 2000, Loss: 19.1379, Val Loss: 15.3196,Hit Rate: 60.46%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 139.71it/s]
# 2024-02-26 21:29:39.966 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 97 / 2000, Loss: 19.1557, Val Loss: 15.3434,Hit Rate: 60.52%, Val Hit Rate: 61.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 151.51it/s]
# 2024-02-26 21:29:40.226 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 98 / 2000, Loss: 19.1820, Val Loss: 15.3828,Hit Rate: 60.52%, Val Hit Rate: 62.32%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 140.62it/s]
# 2024-02-26 21:29:40.504 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 99 / 2000, Loss: 19.2297, Val Loss: 15.4650,Hit Rate: 60.39%, Val Hit Rate: 62.32%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 134.63it/s]
# 2024-02-26 21:29:40.799 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 100 / 2000, Loss: 19.3512, Val Loss: 15.6939,Hit Rate: 60.70%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 151.56it/s]
# 2024-02-26 21:29:41.066 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 101 / 2000, Loss: 19.6373, Val Loss: 16.2375,Hit Rate: 60.70%, Val Hit Rate: 62.75%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 180.49it/s]
# 2024-02-26 21:29:41.288 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 102 / 2000, Loss: 19.8054, Val Loss: 16.5308,Hit Rate: 60.58%, Val Hit Rate: 62.75%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 153.36it/s]
# 2024-02-26 21:29:41.548 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 103 / 2000, Loss: 19.8638, Val Loss: 16.5915,Hit Rate: 60.52%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 132.12it/s]
# 2024-02-26 21:29:41.832 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 104 / 2000, Loss: 19.8984, Val Loss: 16.6118,Hit Rate: 60.46%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 164.48it/s]
# 2024-02-26 21:29:42.083 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 105 / 2000, Loss: 19.9282, Val Loss: 16.6249,Hit Rate: 60.46%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 173.88it/s]
# 2024-02-26 21:29:42.307 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 106 / 2000, Loss: 19.9521, Val Loss: 16.6333,Hit Rate: 60.52%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 140.83it/s]
# 2024-02-26 21:29:42.583 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 107 / 2000, Loss: 19.9735, Val Loss: 16.6392,Hit Rate: 60.39%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 136.80it/s]
# 2024-02-26 21:29:42.874 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 108 / 2000, Loss: 19.9926, Val Loss: 16.6416,Hit Rate: 60.39%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 136.79it/s]
# 2024-02-26 21:29:43.143 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 109 / 2000, Loss: 20.0093, Val Loss: 16.6428,Hit Rate: 60.39%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 168.19it/s]
# 2024-02-26 21:29:43.374 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 110 / 2000, Loss: 20.0260, Val Loss: 16.6428,Hit Rate: 60.33%, Val Hit Rate: 62.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 167.12it/s]
# 2024-02-26 21:29:43.627 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 111 / 2000, Loss: 20.0427, Val Loss: 16.6392,Hit Rate: 61.19%, Val Hit Rate: 63.47%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 146.02it/s]
# 2024-02-26 21:29:43.901 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 112 / 2000, Loss: 20.0653, Val Loss: 16.6309,Hit Rate: 61.32%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 183.69it/s]
# 2024-02-26 21:29:44.126 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 113 / 2000, Loss: 20.1237, Val Loss: 16.5749,Hit Rate: 61.32%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 181.12it/s]
# 2024-02-26 21:29:44.342 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 114 / 2000, Loss: 20.2501, Val Loss: 16.1469,Hit Rate: 60.52%, Val Hit Rate: 62.89%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 173.35it/s]
# 2024-02-26 21:29:44.567 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 115 / 2000, Loss: 20.3001, Val Loss: 16.1111,Hit Rate: 61.69%, Val Hit Rate: 63.75%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 178.46it/s]
# 2024-02-26 21:29:44.794 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 116 / 2000, Loss: 20.3311, Val Loss: 16.1016,Hit Rate: 61.62%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 183.03it/s]
# 2024-02-26 21:29:45.012 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 117 / 2000, Loss: 20.3490, Val Loss: 16.0778,Hit Rate: 61.69%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 167.16it/s]
# 2024-02-26 21:29:45.240 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 118 / 2000, Loss: 20.3633, Val Loss: 16.0658,Hit Rate: 61.81%, Val Hit Rate: 64.04%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 203.86it/s]
# 2024-02-26 21:29:45.439 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 119 / 2000, Loss: 20.3764, Val Loss: 16.0539,Hit Rate: 61.75%, Val Hit Rate: 63.90%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 166.44it/s]
# 2024-02-26 21:29:45.670 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 120 / 2000, Loss: 20.3884, Val Loss: 16.0432,Hit Rate: 61.62%, Val Hit Rate: 63.75%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 155.75it/s]
# 2024-02-26 21:29:45.909 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 121 / 2000, Loss: 20.3991, Val Loss: 16.0336,Hit Rate: 61.62%, Val Hit Rate: 63.75%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 181.14it/s]
# 2024-02-26 21:29:46.118 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 122 / 2000, Loss: 20.4086, Val Loss: 16.0253,Hit Rate: 61.69%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.89it/s]
# 2024-02-26 21:29:46.344 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 123 / 2000, Loss: 20.4182, Val Loss: 16.0170,Hit Rate: 61.69%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 184.95it/s]
# 2024-02-26 21:29:46.556 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 124 / 2000, Loss: 20.4265, Val Loss: 16.0086,Hit Rate: 61.69%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 161.43it/s]
# 2024-02-26 21:29:46.797 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 125 / 2000, Loss: 20.4337, Val Loss: 16.0015,Hit Rate: 61.56%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 177.42it/s]
# 2024-02-26 21:29:47.028 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 126 / 2000, Loss: 20.4420, Val Loss: 15.9943,Hit Rate: 61.62%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 187.67it/s]
# 2024-02-26 21:29:47.230 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 127 / 2000, Loss: 20.4492, Val Loss: 15.9872,Hit Rate: 61.81%, Val Hit Rate: 63.47%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 183.70it/s]
# 2024-02-26 21:29:47.456 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 128 / 2000, Loss: 20.4551, Val Loss: 15.9800,Hit Rate: 61.87%, Val Hit Rate: 63.47%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 202.20it/s]
# 2024-02-26 21:29:47.665 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 129 / 2000, Loss: 20.4623, Val Loss: 15.9740,Hit Rate: 61.99%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.23it/s]
# 2024-02-26 21:29:47.895 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 130 / 2000, Loss: 20.4682, Val Loss: 15.9681,Hit Rate: 61.99%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 147.27it/s]
# 2024-02-26 21:29:48.153 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 131 / 2000, Loss: 20.4742, Val Loss: 15.9621,Hit Rate: 61.99%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 164.51it/s]
# 2024-02-26 21:29:48.388 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 132 / 2000, Loss: 20.4790, Val Loss: 15.9562,Hit Rate: 61.99%, Val Hit Rate: 63.61%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 176.24it/s]
# 2024-02-26 21:29:48.608 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 133 / 2000, Loss: 20.4849, Val Loss: 15.9502,Hit Rate: 66.54%, Val Hit Rate: 69.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 158.02it/s]
# 2024-02-26 21:29:48.846 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 134 / 2000, Loss: 20.4897, Val Loss: 15.9442,Hit Rate: 66.54%, Val Hit Rate: 69.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 191.84it/s]
# 2024-02-26 21:29:49.063 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 135 / 2000, Loss: 20.4945, Val Loss: 15.9395,Hit Rate: 66.54%, Val Hit Rate: 69.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 183.03it/s]
# 2024-02-26 21:29:49.285 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 136 / 2000, Loss: 20.4992, Val Loss: 15.9335,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 169.34it/s]
# 2024-02-26 21:29:49.516 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 137 / 2000, Loss: 20.5040, Val Loss: 15.9287,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 167.68it/s]
# 2024-02-26 21:29:49.742 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 138 / 2000, Loss: 20.5088, Val Loss: 15.9240,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 193.48it/s]
# 2024-02-26 21:29:49.960 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 139 / 2000, Loss: 20.5123, Val Loss: 15.9192,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 200.65it/s]
# 2024-02-26 21:29:50.158 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 140 / 2000, Loss: 20.5171, Val Loss: 15.9144,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.23it/s]
# 2024-02-26 21:29:50.385 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 141 / 2000, Loss: 20.5207, Val Loss: 15.9097,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 186.34it/s]
# 2024-02-26 21:29:50.606 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 142 / 2000, Loss: 20.5243, Val Loss: 15.9049,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 181.16it/s]
# 2024-02-26 21:29:50.821 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 143 / 2000, Loss: 20.5290, Val Loss: 15.9001,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 193.94it/s]
# 2024-02-26 21:29:51.029 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 144 / 2000, Loss: 20.5326, Val Loss: 15.8954,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 176.23it/s]
# 2024-02-26 21:29:51.249 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 145 / 2000, Loss: 20.5362, Val Loss: 15.8906,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 174.41it/s]
# 2024-02-26 21:29:51.490 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 146 / 2000, Loss: 20.5386, Val Loss: 15.8870,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 188.84it/s]
# 2024-02-26 21:29:51.695 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 147 / 2000, Loss: 20.5421, Val Loss: 15.8823,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 141.34it/s]
# 2024-02-26 21:29:51.985 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 148 / 2000, Loss: 20.5457, Val Loss: 15.8787,Hit Rate: 67.59%, Val Hit Rate: 70.92%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 132.29it/s]
# 2024-02-26 21:29:52.284 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 149 / 2000, Loss: 20.5481, Val Loss: 15.8739,Hit Rate: 67.59%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 129.29it/s]
# 2024-02-26 21:29:52.575 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 150 / 2000, Loss: 20.5517, Val Loss: 15.8703,Hit Rate: 67.59%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 140.10it/s]
# 2024-02-26 21:29:52.855 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 151 / 2000, Loss: 20.5541, Val Loss: 15.8668,Hit Rate: 67.65%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 155.14it/s]
# 2024-02-26 21:29:53.084 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 152 / 2000, Loss: 20.5576, Val Loss: 15.8632,Hit Rate: 67.65%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 172.10it/s]
# 2024-02-26 21:29:53.306 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 153 / 2000, Loss: 20.5600, Val Loss: 15.8596,Hit Rate: 67.65%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 167.68it/s]
# 2024-02-26 21:29:53.529 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 154 / 2000, Loss: 20.5624, Val Loss: 15.8560,Hit Rate: 67.59%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 183.04it/s]
# 2024-02-26 21:29:53.755 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 155 / 2000, Loss: 20.5648, Val Loss: 15.8525,Hit Rate: 67.59%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 194.63it/s]
# 2024-02-26 21:29:53.954 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 156 / 2000, Loss: 20.5672, Val Loss: 15.8489,Hit Rate: 67.65%, Val Hit Rate: 71.20%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 172.10it/s]
# 2024-02-26 21:29:54.165 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 157 / 2000, Loss: 20.5696, Val Loss: 15.8453,Hit Rate: 67.65%, Val Hit Rate: 71.35%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 188.32it/s]
# 2024-02-26 21:29:54.385 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 158 / 2000, Loss: 20.5719, Val Loss: 15.8429,Hit Rate: 67.84%, Val Hit Rate: 71.49%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 185.63it/s]
# 2024-02-26 21:29:54.764 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 159 / 2000, Loss: 20.5743, Val Loss: 15.8393,Hit Rate: 67.84%, Val Hit Rate: 71.49%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 188.33it/s]
# 2024-02-26 21:29:54.989 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 160 / 2000, Loss: 20.5767, Val Loss: 15.8370,Hit Rate: 67.84%, Val Hit Rate: 71.49%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 169.97it/s]
# 2024-02-26 21:29:55.207 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 161 / 2000, Loss: 20.5791, Val Loss: 15.8346,Hit Rate: 67.84%, Val Hit Rate: 71.49%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 158.01it/s]
# 2024-02-26 21:29:55.446 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 162 / 2000, Loss: 20.5803, Val Loss: 15.8310,Hit Rate: 67.84%, Val Hit Rate: 71.49%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 163.45it/s]
# 2024-02-26 21:29:55.684 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 163 / 2000, Loss: 20.5827, Val Loss: 15.8286,Hit Rate: 67.84%, Val Hit Rate: 71.49%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 186.98it/s]
# 2024-02-26 21:29:55.901 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 164 / 2000, Loss: 20.5851, Val Loss: 15.8262,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 203.87it/s]
# 2024-02-26 21:29:56.098 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 165 / 2000, Loss: 20.5863, Val Loss: 15.8238,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 144.01it/s]
# 2024-02-26 21:29:56.368 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 166 / 2000, Loss: 20.5886, Val Loss: 15.8215,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 159.91it/s]
# 2024-02-26 21:29:56.607 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 167 / 2000, Loss: 20.5898, Val Loss: 15.8191,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 191.67it/s]
# 2024-02-26 21:29:56.821 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 168 / 2000, Loss: 20.5922, Val Loss: 15.8167,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 169.87it/s]
# 2024-02-26 21:29:57.051 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 169 / 2000, Loss: 20.5934, Val Loss: 15.8155,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 184.33it/s]
# 2024-02-26 21:29:57.263 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 170 / 2000, Loss: 20.5958, Val Loss: 15.8131,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 191.04it/s]
# 2024-02-26 21:29:57.472 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 171 / 2000, Loss: 20.5970, Val Loss: 15.8107,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 169.18it/s]
# 2024-02-26 21:29:57.694 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 172 / 2000, Loss: 20.5994, Val Loss: 15.8083,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 187.69it/s]
# 2024-02-26 21:29:57.894 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 173 / 2000, Loss: 20.6006, Val Loss: 15.8072,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 179.89it/s]
# 2024-02-26 21:29:58.121 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 174 / 2000, Loss: 20.6017, Val Loss: 15.8048,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 183.71it/s]
# 2024-02-26 21:29:58.336 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 175 / 2000, Loss: 20.6041, Val Loss: 15.8036,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 173.87it/s]
# 2024-02-26 21:29:58.564 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 176 / 2000, Loss: 20.6053, Val Loss: 15.8012,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 202.24it/s]
# 2024-02-26 21:29:58.768 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 177 / 2000, Loss: 20.6065, Val Loss: 15.8000,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 178.00it/s]
# 2024-02-26 21:29:58.979 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 178 / 2000, Loss: 20.6077, Val Loss: 15.7976,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 184.36it/s]
# 2024-02-26 21:29:59.204 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 179 / 2000, Loss: 20.6089, Val Loss: 15.7964,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 193.25it/s]
# 2024-02-26 21:29:59.404 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 180 / 2000, Loss: 20.6113, Val Loss: 15.7940,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 180.24it/s]
# 2024-02-26 21:29:59.610 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 181 / 2000, Loss: 20.6125, Val Loss: 15.7928,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 203.06it/s]
# 2024-02-26 21:29:59.828 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 182 / 2000, Loss: 20.6137, Val Loss: 15.7905,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 181.76it/s]
# 2024-02-26 21:30:00.053 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 183 / 2000, Loss: 20.6149, Val Loss: 15.7893,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 165.52it/s]
# 2024-02-26 21:30:00.292 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 184 / 2000, Loss: 20.6161, Val Loss: 15.7881,Hit Rate: 67.84%, Val Hit Rate: 71.63%
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 169.35it/s]
# 2024-02-26 21:30:00.527 | INFO     | quantified_strategies.ml_utils:train:162 - Epoch: 185 / 2000, Loss: 20.6172, Val Loss: 15.7857,Hit Rate: 67.84%, Val Hit Rate: 71.63%
#   0%|                                                                                           | 0/26 [00:00<?, ?it/s]

# %% [markdown]
# ## Visualise Neural Network

# %%
n_sample = 1
training_data = False

viz_nn.visualize_layer_activations(
    fig=plt.figure(figsize=(12, 12)), 
    network=my_net,
    X=(X_train[n_sample] if training_data else X_test[n_sample]).reshape(-1, orig_X_total.shape[1]),
    y=y_train[n_sample] if training_data else y_test[n_sample],
    X_labels=orig_X_total.columns.tolist(),
    y_labels=ASSETS,
)

# %% [markdown]
# ## Plot Loss

# %%
MODEL_NAME = f"{Net.MODEL_TYPE}-model-latest"
plot_utils.create_loss_graph(model_name=MODEL_NAME)

# %%
# raise ValueError

# %% [markdown]
# ## Apply Asset Allocator

# %%
LOAD_MODEL = False

# %%
X_total_df, y_total_df = get_data(assets=ASSETS, is_classification=False)
X_train_df, X_test_df, y_train_df, y_test_df = ml_utils.split_data(X=X_total_df, y=y_total_df)

# %%
if LOAD_MODEL:
    model = Net.load(input_shape=X_total_df.shape[1], output_shape=y_total_df.shape[1], name="latest")
else:
    model = my_net
model

# %%
X_train_tensor, _ = ml_utils.convert_data_to_tensors(X=X_train_df, y=y_train_df)
X_test_tensor, _ = ml_utils.convert_data_to_tensors(X=X_test_df, y=y_test_df)

# %%
def run(X_df: pd.DataFrame, y_df: pd.DataFrame, is_train: bool = True):
    # Convert data to tensor
    X_tensor, _ = ml_utils.convert_data_to_tensors(X=X_df, y=y_df)

    # Get allocation
    allocation = pd.DataFrame(model(X_tensor).detach().numpy(), index=y_df.index, columns=y_df.columns)

    # Get Strategy returns
    hodl_ret = y_df.loc[:, y_df.columns != CASH].mean(axis=1)
    strat_ret = (y_df * allocation).sum(axis=1)
    strat_pos = allocation.loc[:, allocation.columns != CASH].sum(axis=1).round(3)

    cum_hodl_ret = strategy_utils.get_cumulative_return(returns=hodl_ret, total=False)
    cum_strat_ret = strategy_utils.get_cumulative_return(returns=strat_ret, total=False)

    hodl_dd = strategy_utils.get_drawdown_statistics(returns=hodl_ret)["drawdown"]
    strat_dd = strategy_utils.get_drawdown_statistics(returns=strat_ret)["drawdown"]

    prop_cycle = plt.rcParams["axes.prop_cycle"]
    colors = prop_cycle.by_key()["color"]
    color_map = {"strategy": colors[0], "hodl": colors[1]}

    fig, ax = plt.subplots(figsize=(15, 7))

    ax.plot(cum_hodl_ret, label="HODL", color=color_map["hodl"])
    ax.plot(cum_strat_ret, label="Strategy", color=color_map["strategy"])
    ax.fill_between(
        cum_hodl_ret.index,
        0, cum_strat_ret - cum_hodl_ret,
        alpha=0.2, color="blue",
        label="Strategy - HODL",
    )
    ax.plot(hodl_dd, alpha=0.2, label="HODL: DD", color=color_map["hodl"])
    ax.plot(strat_dd, alpha=0.2, label="Strategy: DD", color=color_map["strategy"])

    if is_train:
        plt.title("Strategy: Training")
    else:
        plt.title("Strategy: Test")
    plt.legend(loc="upper left")
    plt.show()

    description = pd.concat([
        strategy_utils.describe(returns=strat_ret, pos=strat_pos, daily=True).to_frame(name="strategy"),
        strategy_utils.describe(returns=hodl_ret, daily=True).to_frame(name="hodl")
    ], axis=1)
    
    return description

# %%
run(X_df=X_train_df, y_df=y_train_df, is_train=True)

# %%
run(X_df=X_test_df, y_df=y_test_df, is_train=False)
